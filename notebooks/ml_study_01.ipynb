# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.3'

# %%
1 + 1
# Out:
# 2

# %%
import pandas as pd

data = {
    "名前": ["なっちゃん", "メンゴ", "チャピ衛門"],
    "年齢": [30, 29, 999],
    "好き": ["ホラー", "ゲーム", "統計"]
}

df = pd.DataFrame(data)

df
# Out:
#       名前   年齢   好き
# 0  なっちゃん   30  ホラー
# 1    メンゴ   29  ゲーム
# 2  チャピ衛門  999   統計

# %%
df["年齢"]
# Out:
# 0     30
# 1     29
# 2    999
# Name: 年齢, dtype: int64

# %%
import numpy as np

a = np.array([1, 2, 3])

a
# Out:
# array([1, 2, 3])

# %%
a * 10
# Out:
# array([10, 20, 30])
